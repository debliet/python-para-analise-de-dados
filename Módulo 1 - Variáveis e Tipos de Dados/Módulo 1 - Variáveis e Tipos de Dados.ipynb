# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Python: Variáveis & Tipos de Dados
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Introdução ao Google Colab;</li>
#   <li>Variáveis;</li>
#   <li>Números;</li>
#   <li><i>Strings;</i></li>
#   <li>Boleanos.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Google Colab

# %% [markdown]
# Crie uma célula de código que escreva o texto "Olá mundo!", utilize o comando `print`.

# %%
print('Olá mundo!')
# Out:
# Olá mundo!

# %% [markdown]
# Crie uma célula de texto e adicione uma imagem.

# %% [markdown]
# ![chkchk.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Números

# %% [markdown]
# Preencha as células de código para preencher os valores de (A), (B) e (C) na tabela de ticket médio abaixo:
#
# <br>
#
# | Dia   | Valor Total Vendas | Qtd Total Vendas | Ticket Medio |
# |-------|--------------------|------------------|--------------|
# | 19/01 | (A)                | 3                | 320.52       |
# | 20/01 | 834.47             | (B)              | 119.21       |
# | 23/01 | 15378.12           | 5                | (C)          |

# %%
# (A)
qtv_19 = 3
tkt_19 = 320.52

a = tkt_19 * sqv_19
print(a)
# Out:
# 961.56

# %%
# (B)
vtv_20 = 834.47
tkt_20 = 119.21

b = vtv_20 / tkt_20
print(int(b))
# Out:
# 7

# %%
# (C)
vtv_23 = 15378.12
qtv_23 = 5

c = vtv_23 / qtv_23
print(c)
# Out:
# 3075.6240000000003

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Strings

# %% [markdown]
# Aplique três métodos distintos na *string* abaixo, você pode conferir alguns métodos neste [link](https://www.w3schools.com/python/python_ref_string.asp):

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'

# %%
# Converts a string into lower case
print(cancao.lower())

# Returns True if all characters in the string are in the alphabet
print(cancao.isalpha())

# Returns a string where a specified value is replaced with a specified value
print(cancao.replace('pião','gatinho'))
# Out:
# roda mundo, roda gigante, roda moinho, roda pião.
# False
# Roda mundo, roda gigante, roda moinho, roda gatinho.

# %% [markdown]
# Extraia da string abaixo o valor da taxa **selic** na variável `selic` e o valor do **ano** na variavel `ano`. Imprima os valores na tela.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'

# %%
posicao_um = noticia.find('2')
posicao_dois = noticia.find('%')

#print(posicao_um)
#print(posicao_dois)

selic = noticia[12:17]
print(f'O valor da taxa selic é {selic}.')


ano = noticia.find('ano')

#print(posicao_ano)

ano = noticia[62]
print(f'O valor do ano é {ano}.')
# Out:
# O valor da taxa selic é 2,75%.
# O valor do ano é 6.

# %% [markdown]
# ---

# %% [markdown]
# ## 4\. Booleanos

# %% [markdown]
# Utilize a tabela da verdade para responder: qual o valor da variável x?

# %%
a = False
b = True

x = not a & b

# %%
print(f'O valor da variável x é {x}')
# Out:
# O valor da variável x é True
